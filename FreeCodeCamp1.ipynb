# %%
import numpy as pd

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sales = pd.read_csv('sales_data.csv')

# %%
sales.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
sales['Customer_Age'].mean()
# Out:
# 35.91921157861212

# %%
sales['Customer_Age'].plot(kind='kde', figsize=(14,6))
# Out:
# <Axes: ylabel='Density'>

# %%
sales['Customer_Age'].plot(kind='box', vert=False,figsize=(14,6))
# Out:
# <Axes: >

# %%
sales['Order_Quantity'].mean()
# Out:
# 11.901659648253654

# %%
sales['Order_Quantity'].plot(kind='hist',bins=30,figsize=(14,6))
# Out:
# <Axes: ylabel='Frequency'>

# %%
sales['Order_Quantity'].plot(kind='box', vert= False, figsize=(14,6))
# Out:
# <Axes: >

# %%
sales['Year'].value_counts()
# Out:
# Year
# 2014    29398
# 2016    29398
# 2013    24443
# 2015    24443
# 2012     2677
# 2011     2677
# Name: count, dtype: int64

# %%
sales['Year'].value_counts().plot(kind='pie', figsize=(6,6))
# Out:
# <Axes: ylabel='count'>

# %%
sales['Month'].value_counts()
# Out:
# Month
# June         11234
# December     11200
# May          11128
# April        10182
# March         9674
# January       9284
# February      9022
# October       8750
# November      8734
# August        8200
# September     8166
# July          7462
# Name: count, dtype: int64

# %%
sales['Month'].value_counts().shape
# Out:
# (12,)

# %%
sales['Month'].value_counts().plot(kind='pie', figsize=(15,8))
# Out:
# <Axes: ylabel='count'>

# %%
sales['Month'].value_counts().plot(kind='bar',figsize=(14,6))
# Out:
# <Axes: xlabel='Month'>

# %%
sales['Month'].shape
# Out:
# (113036,)

# %%
sales['Country'].value_counts()
# Out:
# Country
# United States     39206
# Australia         23936
# Canada            14178
# United Kingdom    13620
# Germany           11098
# France            10998
# Name: count, dtype: int64

# %%
sales['Country'].value_counts().head(1)
# Out:
# Country
# United States    39206
# Name: count, dtype: int64

# %%
sales['Country'].value_counts().head(5)
# Out:
# Country
# United States     39206
# Australia         23936
# Canada            14178
# United Kingdom    13620
# Germany           11098
# Name: count, dtype: int64

# %%
sales['Country'].value_counts().head(10).plot(kind='bar',figsize=(14,8))
# Out:
# <Axes: xlabel='Country'>

# %%
sales.info
# Out:
# <bound method DataFrame.info of               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
# 113032  2014-04-02    2     April  2014            18     Youth (<25)
# 113033  2016-04-02    2     April  2016            18     Youth (<25)
# 113034  2014-03-04    4     March  2014            37  Adults (35-64)
# 113035  2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
sales['Product'].unique()
# Out:
# array(['Hitch Rack - 4-Bike', 'All-Purpose Bike Stand',
#        'Mountain Bottle Cage', 'Water Bottle - 30 oz.',
#        'Road Bottle Cage', 'AWC Logo Cap', 'Bike Wash - Dissolver',
#        'Fender Set - Mountain', 'Half-Finger Gloves, L',
#        'Half-Finger Gloves, M', 'Half-Finger Gloves, S',
#        'Sport-100 Helmet, Black', 'Sport-100 Helmet, Red',
#        'Sport-100 Helmet, Blue', 'Hydration Pack - 70 oz.',
#        'Short-Sleeve Classic Jersey, XL',
#        'Short-Sleeve Classic Jersey, L', 'Short-Sleeve Classic Jersey, M',
#        'Short-Sleeve Classic Jersey, S', 'Long-Sleeve Logo Jersey, M',
#        'Long-Sleeve Logo Jersey, XL', 'Long-Sleeve Logo Jersey, L',
#        'Long-Sleeve Logo Jersey, S', 'Mountain-100 Silver, 38',
#        'Mountain-100 Silver, 44', 'Mountain-100 Black, 48',
#        'Mountain-100 Silver, 48', 'Mountain-100 Black, 38',
#        'Mountain-200 Silver, 38', 'Mountain-100 Black, 44',
# ...

# %%
sales['Product'].value_counts()
# Out:
# Product
# Water Bottle - 30 oz.      10794
# Patch Kit/8 Patches        10416
# Mountain Tire Tube          6816
# AWC Logo Cap                4358
# Sport-100 Helmet, Red       4220
#                            ...
# Mountain-100 Silver, 48       58
# Mountain-100 Silver, 42       54
# Mountain-500 Silver, 48       40
# Road-650 Red, 52              32
# Mountain-500 Black, 52        22
# Name: count, Length: 130, dtype: int64

# %%
sales['Product'].value_counts().head(10).plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='Product'>

# %%
sales.plot(kind='scatter',x='Unit_Cost',y='Unit_Price',figsize=(14,6))
# Out:
# <Axes: xlabel='Unit_Cost', ylabel='Unit_Price'>

# %%
sales.plot(kind='scatter',x='Order_Quantity',y='Profit',figsize=(14,6))
# Out:
# <Axes: xlabel='Order_Quantity', ylabel='Profit'>

# %%
sales[['Profit','Country']].boxplot(by='Country')
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='[Country]'>

# %%
sales[['Customer_Age','Country']].boxplot(by='Country')
# Out:
# <Axes: title={'center': 'Customer_Age'}, xlabel='[Country]'>

# %%
sales['Calculated_Date']=sales[['Year','Month','Day']].apply(lambda x:'{}-{}-{}'.format(x[0],x[1],x[2]),axis=1)
# Out:
# /tmp/ipykernel_1876/961172604.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sales['Calculated_Date']=sales[['Year','Month','Day']].apply(lambda x:'{}-{}-{}'.format(x[0],x[1],x[2]),axis=1)

# %%
sales['Calculated_Date'].head()
# Out:
# 0    2013-November-26
# 1    2015-November-26
# 2       2014-March-23
# 3       2016-March-23
# 4         2014-May-15
# Name: Calculated_Date, dtype: object

# %%
sales['Calculated_Date']=pd.to_datetime(sales['Calculated_Date'])

# %%
sales['Calculated_Date'].head()
# Out:
# 0   2013-11-26
# 1   2015-11-26
# 2   2014-03-23
# 3   2016-03-23
# 4   2014-05-15
# Name: Calculated_Date, dtype: datetime64[ns]

# %%
sales['Calculated_Date'].plot(kind='line',x='Calculated_Date',y='sales[Product].values_counts')
# Out:
# <Axes: >

# %%
sales['Calculated_Date'].value_counts().plot(kind='line', figsize=(14,6))
# Out:
# <Axes: xlabel='Calculated_Date'>

# %%
sales['Revenue']=sales['Revenue']+50

# %%
sales['Revenue'].head()
# Out:
# 0    1000
# 1    1000
# 2    2451
# 3    2138
# 4     468
# Name: Revenue, dtype: int64

# %%
sales['Revenue']+=50

# %%
sales.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
sales.loc[(sales['Country']=='Canada')|(sales['Country']=='France')].shape[0]
# Out:
# 25176

# %%
sales.loc[(sales['Country']=='Canada')].value_counts()
# Out:
# Date        Day  Month      Year  Customer_Age  Age_Group             Customer_Gender  Country  State             Product_Category  Sub_Category       Product                    Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  Revenue  Calculated_Date
# 2016-03-29  29   March      2016  33            Young Adults (25-34)  F                Canada   British Columbia  Accessories       Tires and Tubes    Mountain Tire Tube         24              2          5           71      48    219      2016-03-29         3
# 2014-03-17  17   March      2014  35            Adults (35-64)        M                Canada   British Columbia  Accessories       Bottles and Cages  Water Bottle - 30 oz.      15              2          5           44      30    174      2014-03-17         3
# ...

# %%
sales.loc[(sales['Sub_Category']=='Bike Racks')&(sales['Country']=='Canada')].shape[0]
# Out:
# 104

# %%
sales.loc[(sales['Country'] == 'Canada') & (sales['Sub_Category'] == 'Bike Racks')].shape[0]
# Out:
# 104

# %%
sales.loc[sales['Country']=='France','State']
# Out:
# 50        Seine Saint Denis
# 51        Seine Saint Denis
# 52                  Moselle
# 53                  Moselle
# 60                     Nord
#                 ...
# 112979              Essonne
# 113000              Essonne
# 113001              Essonne
# 113034        Seine (Paris)
# 113035        Seine (Paris)
# Name: State, Length: 10998, dtype: object

# %%
sales.loc[sales['Country']=='France','State'].value_counts()
# Out:
# State
# Seine (Paris)        2328
# Seine Saint Denis    1684
# Nord                 1670
# Hauts de Seine       1084
# Essonne               994
# Yveline               954
# Seine et Marne        394
# Moselle               386
# Loiret                382
# Val d'Oise            264
# Garonne (Haute)       208
# Val de Marne          158
# Charente-Maritime     148
# Somme                 134
# Loir et Cher          120
# Pas de Calais          90
# Name: count, dtype: int64

# %%
sales.loc[sales['Country']=='France','State'].value_counts().plot(kind='bar',figsize=(14,6))
# Out:
# <Axes: xlabel='State'>

# %%
sales['Product_Category'].value_counts()
# Out:
# Product_Category
# Accessories    70120
# Bikes          25982
# Clothing       16934
# Name: count, dtype: int64

# %%
sales['Product_Category'].value_counts().plot(kind='pie',figsize=(6,6))
# Out:
# <Axes: ylabel='count'>

# %%
sales['Sub_Category'].value_counts().plot(kind='pie',figsize=(6,6))
# Out:
# <Axes: ylabel='count'>

# %%
sales['Sub_Category'].value_counts()
# Out:
# Sub_Category
# Tires and Tubes      33870
# Bottles and Cages    15876
# Road Bikes           13430
# Helmets              12158
# Mountain Bikes        8854
# Jerseys               6010
# Caps                  4358
# Fenders               4032
# Touring Bikes         3698
# Gloves                2686
# Cleaners              1802
# Shorts                1794
# Hydration Packs       1334
# Socks                 1122
# Vests                  964
# Bike Racks             592
# Bike Stands            456
# Name: count, dtype: int64

# %%
accessories = sales.loc[sales['Product_Category'] == 'Accessories', 'Sub_Category'].value_counts()

# %%
accessories
# Out:
# Sub_Category
# Tires and Tubes      33870
# Bottles and Cages    15876
# Helmets              12158
# Fenders               4032
# Cleaners              1802
# Hydration Packs       1334
# Bike Racks             592
# Bike Stands            456
# Name: count, dtype: int64

# %%
sales.loc[sales['Product_Category']=='Accesoroes','Sub_Category']
# Out:
# Series([], Name: Sub_Category, dtype: object)

# %%
sales.loc[sales['Product_Category']=='Accesoroes','Sub_Category'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
sales.loc[sales['Product_Category'] == 'Accessories', 'Sub_Category'].value_counts()
# Out:
# Sub_Category
# Tires and Tubes      33870
# Bottles and Cages    15876
# Helmets              12158
# Fenders               4032
# Cleaners              1802
# Hydration Packs       1334
# Bike Racks             592
# Bike Stands            456
# Name: count, dtype: int64

# %%
sales.loc[sales['Product_Category'] == 'Accessories', 'Sub_Category'].value_counts().plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='Sub_Category'>

# %%
sales.loc[sales['Product_Category']=='Bikes','Sub_Category'].value_counts()
# Out:
# Sub_Category
# Road Bikes        13430
# Mountain Bikes     8854
# Touring Bikes      3698
# Name: count, dtype: int64

# %%
bike = sales.loc[sales['Product_Category']=='Bikes','Sub_Category'].value_counts()

# %%
bike
# Out:
# Sub_Category
# Road Bikes        13430
# Mountain Bikes     8854
# Touring Bikes      3698
# Name: count, dtype: int64

# %%
bike.plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
sales['Customer_Gender'].value_counts()
# Out:
# Customer_Gender
# M    58312
# F    54724
# Name: count, dtype: int64

# %%
sales['Customer_Gender'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Customer_Gender'>

# %%
sales['Customer_Gender']=='M'
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4         False
#           ...
# 113031     True
# 113032     True
# 113033     True
# 113034    False
# 113035    False
# Name: Customer_Gender, Length: 113036, dtype: bool

# %%
sales.loc[sales['Customer_Gender']=='M'].shape[0]
# Out:
# 58312

# %%
sales.loc[(sales['Customer_Gender']=='M') & (sales['Revenue']==500)]
# Out:
#              Date  Day     Month  Year  Customer_Age             Age_Group  \
# 23093  2016-04-22   22     April  2016            33  Young Adults (25-34)
# 23135  2015-10-31   31   October  2015            58        Adults (35-64)
# 23377  2016-06-19   19      June  2016            32  Young Adults (25-34)
# 27454  2013-12-31   31  December  2013            32  Young Adults (25-34)
# 28520  2014-05-02    2       May  2014            43        Adults (35-64)
# 28657  2015-12-01    1  December  2015            55        Adults (35-64)
# 28727  2016-05-19   19       May  2016            20           Youth (<25)
# 29316  2014-04-17   17     April  2014            21           Youth (<25)
# 29484  2014-07-05    5      July  2014            38        Adults (35-64)
#
#       Customer_Gender        Country       State Product_Category  \
# 23093               M      Australia    Victoria      Accessories
# 23135               M      Australia    Victoria      Accessories
# ...

# %%
sales.loc[(sales['Customer_Gender']=='M') & (sales['Revenue']==500)].shape[0]
# Out:
# 9

# %%
sales.loc[(sales['Customer_Gender']=='M') & (sales['Revenue']>500)].shape[0]
# Out:
# 24843

# %%
sales.loc[(sales['Customer_Gender']=='M') & (sales['Revenue']>500)]
# Out:
#               Date  Day     Month  Year  Customer_Age             Age_Group  \
# 0       2013-11-26   26  November  2013            19           Youth (<25)
# 1       2015-11-26   26  November  2015            19           Youth (<25)
# 2       2014-03-23   23     March  2014            49        Adults (35-64)
# 3       2016-03-23   23     March  2016            49        Adults (35-64)
# 8       2014-02-22   22  February  2014            35        Adults (35-64)
# ...            ...  ...       ...   ...           ...                   ...
# 113025  2016-04-03    3     April  2016            34  Young Adults (25-34)
# 113026  2013-07-08    8      July  2013            29  Young Adults (25-34)
# 113027  2015-07-08    8      July  2015            29  Young Adults (25-34)
# 113032  2014-04-02    2     April  2014            18           Youth (<25)
# 113033  2016-04-02    2     April  2016            18           Youth (<25)
#
# ...

# %%
sales['Revenue'].head(5)
# Out:
# 0    1050
# 1    1050
# 2    2501
# 3    2188
# 4     518
# Name: Revenue, dtype: int64

# %%
sales.sort_values(['Revenue'], ascending=False).head(5)
# Out:
#               Date  Day      Month  Year  Customer_Age       Age_Group  \
# 112073  2015-07-24   24       July  2015            52  Adults (35-64)
# 112072  2013-07-24   24       July  2013            52  Adults (35-64)
# 71129   2011-07-08    8       July  2011            22     Youth (<25)
# 70307   2011-04-30   30      April  2011            44  Adults (35-64)
# 70601   2011-09-30   30  September  2011            19     Youth (<25)
#
#        Customer_Gender    Country             State Product_Category  \
# 112073               M  Australia        Queensland         Clothing
# 112072               M  Australia        Queensland         Clothing
# 71129                M     Canada           Alberta            Bikes
# 70307                M     Canada  British Columbia            Bikes
# 70601                F     Canada  British Columbia            Bikes
#
#        Sub_Category                  Product  Order_Quantity  Unit_Cost  \
# ...

# %%
sales.sort_values(['Revenue'], ascending=False).head(1)
# Out:
#               Date  Day Month  Year  Customer_Age       Age_Group  \
# 112073  2015-07-24   24  July  2015            52  Adults (35-64)
#
#        Customer_Gender    Country       State Product_Category Sub_Category  \
# 112073               M  Australia  Queensland         Clothing        Vests
#
#                         Product  Order_Quantity  Unit_Cost  Unit_Price  \
# 112073  Touring-1000 Yellow, 50              29       1482        2384
#
#         Profit   Cost  Revenue Calculated_Date
# 112073   15096  42978    58174      2015-07-24

# %%
sales['Revenue'].max()
# Out:
# 58174

# %%
cond = sales['Revenue'] == sales['Revenue'].max()

sales.loc[cond]
# Out:
#               Date  Day Month  Year  Customer_Age       Age_Group  \
# 112073  2015-07-24   24  July  2015            52  Adults (35-64)
#
#        Customer_Gender    Country       State Product_Category Sub_Category  \
# 112073               M  Australia  Queensland         Clothing        Vests
#
#                         Product  Order_Quantity  Unit_Cost  Unit_Price  \
# 112073  Touring-1000 Yellow, 50              29       1482        2384
#
#         Profit   Cost  Revenue Calculated_Date
# 112073   15096  42978    58174      2015-07-24

# %%
sales['Revenue']>10000 & sales ['Order_Quantity']
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 113031    True
# 113032    True
# 113033    True
# 113034    True
# 113035    True
# Length: 113036, dtype: bool

# %%
sales.loc[(sales['Revenue']<10000) , ['Order_Quantity']].mean()
# Out:
# Order_Quantity    11.914618
# dtype: float64

# %%
sales.loc[(sales['Revenue']<10000), ['Order_Quantity']].mean()
# Out:
# Order_Quantity    11.914618
# dtype: float64

# %%
cond = sales['Revenue'] < 10_000

sales.loc[cond, 'Order_Quantity'].mean()
# Out:
# 11.914618369987064

# %%
sales.loc[(sales['Year']==2016)&(sales['Month']=='May')].shape[0]
# Out:
# 5015

# %%
cond = (sales['Year'] == 2016) & (sales['Month'] == 'May')

sales.loc[cond].shape[0]
# Out:
# 5015

# %%
sales.loc[(sales['Year']==2016)&(sales['Month'].isin(['May','June','July']))].shape[0]
# Out:
# 12164

# %%
cond = (sales['Year'] == 2016) & (sales['Month'].isin(['May', 'June', 'July']))

sales.loc[cond].shape[0]
# Out:
# 12164

# %%
sales.loc[(sales['Year']==2016,['Profit','Month'])].boxplot(by='Month',figsize=(14,6))
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='[Month]'>

# %%
profit_2016 = sales.loc[sales['Year'] == 2016, ['Profit', 'Month']]

profit_2016.boxplot(by='Month', figsize=(14,6))
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='[Month]'>

# %%
sales.loc[sales['Country']=='United States','Unit_Price']=sales.loc[sales['Country']=='United States','Unit_Price']*1.07
# Out:
# /tmp/ipykernel_1876/3953444779.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[128.4  128.4  128.4  ...  68.48  68.48  68.48]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sales.loc[sales['Country']=='United States','Unit_Price']=sales.loc[sales['Country']=='United States','Unit_Price']*1.07

# %%
#go again

# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
sales.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
sales['Customer_Age'].mean()
# Out:
# 35.91921157861212

# %%
sales['Customer_Age'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
sales['Order_Quantity'].mean()
# Out:
# 11.901659648253654

# %%
sales['Order_Quantity'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
sales['Order_Quantity'].plot(kind='hist', bins=200)
# Out:
# <Axes: ylabel='Frequency'>

# %%
sales['Order_Quantity'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %%
sales.shape[1]
# Out:
# 19

# %%
sales['Year'].value_counts()
# Out:
# Year
# 2014    29398
# 2016    29398
# 2013    24443
# 2015    24443
# 2012     2677
# 2011     2677
# Name: count, dtype: int64

# %%
sales['Year'].value_counts().plot(kind='box')
# Out:
# <Axes: >

# %%
sales['Year'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
sales['Month'].value_counts()
# Out:
# Month
# June         11234
# December     11200
# May          11128
# April        10182
# March         9674
# January       9284
# February      9022
# October       8750
# November      8734
# August        8200
# September     8166
# July          7462
# Name: count, dtype: int64

# %%
sales['Month'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Month'>

# %%
sales['Country'].value_counts().head(1)
# Out:
# Country
# United States    39206
# Name: count, dtype: int64

# %%
sales['Country'].value_counts()
# Out:
# Country
# United States     39206
# Australia         23936
# Canada            14178
# United Kingdom    13620
# Germany           11098
# France            10998
# Name: count, dtype: int64

# %%
sales['Country'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Country'>

# %%
sales['Product'].unique()
# Out:
# array(['Hitch Rack - 4-Bike', 'All-Purpose Bike Stand',
#        'Mountain Bottle Cage', 'Water Bottle - 30 oz.',
#        'Road Bottle Cage', 'AWC Logo Cap', 'Bike Wash - Dissolver',
#        'Fender Set - Mountain', 'Half-Finger Gloves, L',
#        'Half-Finger Gloves, M', 'Half-Finger Gloves, S',
#        'Sport-100 Helmet, Black', 'Sport-100 Helmet, Red',
#        'Sport-100 Helmet, Blue', 'Hydration Pack - 70 oz.',
#        'Short-Sleeve Classic Jersey, XL',
#        'Short-Sleeve Classic Jersey, L', 'Short-Sleeve Classic Jersey, M',
#        'Short-Sleeve Classic Jersey, S', 'Long-Sleeve Logo Jersey, M',
#        'Long-Sleeve Logo Jersey, XL', 'Long-Sleeve Logo Jersey, L',
#        'Long-Sleeve Logo Jersey, S', 'Mountain-100 Silver, 38',
#        'Mountain-100 Silver, 44', 'Mountain-100 Black, 48',
#        'Mountain-100 Silver, 48', 'Mountain-100 Black, 38',
#        'Mountain-200 Silver, 38', 'Mountain-100 Black, 44',
# ...

# %%
sales['Product'].value_counts().head(10)
# Out:
# Product
# Water Bottle - 30 oz.      10794
# Patch Kit/8 Patches        10416
# Mountain Tire Tube          6816
# AWC Logo Cap                4358
# Sport-100 Helmet, Red       4220
# Road Tire Tube              4176
# Sport-100 Helmet, Black     4152
# Fender Set - Mountain       4032
# Sport-100 Helmet, Blue      3788
# Touring Tire Tube           3702
# Name: count, dtype: int64

# %%
sales['Product'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='Product'>

# %%
sales.plot(kind='scatter', x='Unit_Cost', y='Unit_Price')
# Out:
# <Axes: xlabel='Unit_Cost', ylabel='Unit_Price'>

# %%
sales.plot(kind='scatter',x='Order_Quantity', y='Profit')
# Out:
# <Axes: xlabel='Order_Quantity', ylabel='Profit'>

# %%
sales['Calculated_Date']=sales[['Year','Month','Day']].apply(lambda x:'{}-{}-{}'.format(x[0],x[1],x[2]),axis=1)
# Out:
# /tmp/ipykernel_1876/961172604.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sales['Calculated_Date']=sales[['Year','Month','Day']].apply(lambda x:'{}-{}-{}'.format(x[0],x[1],x[2]),axis=1)

# %%
sales['Calculated_Date'] .head()
# Out:
# 0    2013-November-26
# 1    2015-November-26
# 2       2014-March-23
# 3       2016-March-23
# 4         2014-May-15
# Name: Calculated_Date, dtype: object

# %%
sales['Calculated_Date'] =pd.to_datetime(sales['Calculated_Date'])

# %%
sales['Calculated_Date'].head()
# Out:
# 0   2013-11-26
# 1   2015-11-26
# 2   2014-03-23
# 3   2016-03-23
# 4   2014-05-15
# Name: Calculated_Date, dtype: datetime64[ns]

# %%
sales['Calculated_Date'].value_counts().plot(kind='line')
# Out:
# <Axes: xlabel='Calculated_Date'>

# %%
sales['Revenue']=sales['Revenue']+50

# %%
sales['Country'].value_counts()
# Out:
# Country
# United States     39206
# Australia         23936
# Canada            14178
# United Kingdom    13620
# Germany           11098
# France            10998
# Name: count, dtype: int64

# %%
sales.loc[(sales['Country']=='Canada')| (sales['Country']=='France')].shape[0]
# Out:
# 25176

# %%
sales.loc[(sales['Sub_Category']=='Bike Racks') & (sales['Country']=='Canada')].shape[0]
# Out:
# 104

# %%
sales.loc[sales['Country']=='France', 'State'].value_counts()
# Out:
# State
# Seine (Paris)        2328
# Seine Saint Denis    1684
# Nord                 1670
# Hauts de Seine       1084
# Essonne               994
# Yveline               954
# Seine et Marne        394
# Moselle               386
# Loiret                382
# Val d'Oise            264
# Garonne (Haute)       208
# Val de Marne          158
# Charente-Maritime     148
# Somme                 134
# Loir et Cher          120
# Pas de Calais          90
# Name: count, dtype: int64

# %%
sales.loc[sales['Country']=='Canada', 'State'].value_counts()
# Out:
# State
# British Columbia    14116
# Alberta                56
# Ontario                 6
# Name: count, dtype: int64

# %%
sales.loc[sales['Country']=='Canada', 'State'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='State'>

# %%
sales['Product_Category'].value_counts()
# Out:
# Product_Category
# Accessories    70120
# Bikes          25982
# Clothing       16934
# Name: count, dtype: int64

# %%
sales['Product_Category'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
sales.loc[sales['Product_Category']=='Accessories', 'Sub_Category'].value_counts()
# Out:
# Sub_Category
# Tires and Tubes      33870
# Bottles and Cages    15876
# Helmets              12158
# Fenders               4032
# Cleaners              1802
# Hydration Packs       1334
# Bike Racks             592
# Bike Stands            456
# Name: count, dtype: int64

# %%
sales.loc[sales['Product_Category'] == 'Accessories', 'Sub_Category'].value_counts()
# Out:
# Sub_Category
# Tires and Tubes      33870
# Bottles and Cages    15876
# Helmets              12158
# Fenders               4032
# Cleaners              1802
# Hydration Packs       1334
# Bike Racks             592
# Bike Stands            456
# Name: count, dtype: int64

# %%
sales.loc[sales['Product_Category']=='Bikes', 'Sub_Category'].value_counts()
# Out:
# Sub_Category
# Road Bikes        13430
# Mountain Bikes     8854
# Touring Bikes      3698
# Name: count, dtype: int64

# %%
sales['Customer_Gender'].value_counts()
# Out:
# Customer_Gender
# M    58312
# F    54724
# Name: count, dtype: int64

# %%
sales.loc[(sales['Customer_Gender']=="M")&(sales['Revenue']>500)].shape[0]
# Out:
# 26001

# %%
sales.sort_values(['Revenue'], ascending=False).head(5)
# Out:
#               Date  Day      Month  Year  Customer_Age       Age_Group  \
# 112073  2015-07-24   24       July  2015            52  Adults (35-64)
# 112072  2013-07-24   24       July  2013            52  Adults (35-64)
# 71129   2011-07-08    8       July  2011            22     Youth (<25)
# 70307   2011-04-30   30      April  2011            44  Adults (35-64)
# 70601   2011-09-30   30  September  2011            19     Youth (<25)
#
#        Customer_Gender    Country             State Product_Category  \
# 112073               M  Australia        Queensland         Clothing
# 112072               M  Australia        Queensland         Clothing
# 71129                M     Canada           Alberta            Bikes
# 70307                M     Canada  British Columbia            Bikes
# 70601                F     Canada  British Columbia            Bikes
#
#        Sub_Category                  Product  Order_Quantity  Unit_Cost  \
# ...

# %%
sales.sort_values(['Revenue'], ascending=False).head(1)
# Out:
#               Date  Day Month  Year  Customer_Age       Age_Group  \
# 112073  2015-07-24   24  July  2015            52  Adults (35-64)
#
#        Customer_Gender    Country       State Product_Category Sub_Category  \
# 112073               M  Australia  Queensland         Clothing        Vests
#
#                         Product  Order_Quantity  Unit_Cost  Unit_Price  \
# 112073  Touring-1000 Yellow, 50              29       1482      2384.0
#
#         Profit   Cost  Revenue Calculated_Date
# 112073   15096  42978    58224      2015-07-24

# %%
sales.loc[(sales['Revenue']>10000 , ['Order_Quantity'])].mean()
# Out:
# Order_Quantity    3.685393
# dtype: float64

# %%
cond=sales['Revenue']>10000

# %%
sales.loc[cond,'Order_Quantity'].mean()
# Out:
# 3.6853932584269664

# %%
cond=sales['Revenue']<10000

# %%
sales.loc[cond,'Order_Quantity'].mean()
# Out:
# 11.914618369987064

# %%
sales.loc[(sales['Year']==2016) & (sales['Month']=='May')].shape[0]
# Out:
# 5015

# %%
cond = (sales['Year'] == 2016) & (sales['Month'] == 'May')

sales.loc[cond].shape[0]
# Out:
# 5015

# %%
sales.loc[(sales['Year']==2016) & (sales['Month'].isin(['May','June','July']))].shape[0]
# Out:
# 12164

# %%
sales.loc[sales['Country']=='United States','Unit_Price']=sales.loc[sales['Country']=='United States','Unit_Price']*1.072

# %%
sales.loc[sales['Country']=='United States','Unit_Price'].head()
# Out:
# 22    137.6448
# 23    137.6448
# 34    137.6448
# 35    137.6448
# 38    137.6448
# Name: Unit_Price, dtype: float64

# %%
sales.loc[sales['Country']=='United States','Unit_Price']=sales.loc[sales['Country']=='United States','Unit_Price']*1.072

# %%
sales.loc[sales['Country']=='United States','Unit_Price'].head()
# Out:
# 22    147.555226
# 23    147.555226
# 34    147.555226
# 35    147.555226
# 38    147.555226
# Name: Unit_Price, dtype: float64

# %%
import sqlite3

# %%
__VERSION__ = '0.0.2'

# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymysql

# %%
# !pip install flask-bootstrap
# !pip install flask-wtf

# %%
# !git clone https://github.com/dr-cs/sakila-demo.git
# Out:
# fatal: destination path 'sakila-demo' already exists and is not an empty directory.

# %%
import sqlite3

# %%
conn = sqlite3.connect('data/sakila.db')

df = pd.read_sql('''
    SELECT
        rental.rental_id, rental.rental_date, rental.return_date,
        customer.last_name AS customer_lastname,
        store.store_id,
        city.city AS rental_store_city,
        film.title AS film_title, film.rental_duration AS film_rental_duration,
        film.rental_rate AS film_rental_rate, film.replacement_cost AS film_replacement_cost,
        film.rating AS film_rating
    FROM rental
    INNER JOIN customer ON rental.customer_id == customer.customer_id
    INNER JOIN inventory ON rental.inventory_id == inventory.inventory_id
    INNER JOIN store ON inventory.store_id == store.store_id
    INNER JOIN address ON store.address_id == address.address_id
    INNER JOIN city ON address.city_id == city.city_id
    INNER JOIN film ON inventory.film_id == film.film_id
    ;
''', conn, index_col='rental_id', parse_dates=['rental_date', 'return_date'])
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /RKSRS/Data-Analysis-Example-A-B/FreeCodeCamp1.ipynb Cell 150 line 1
# ----> <a href='vscode-notebook-cell://github%2B7b2276223a312c22726566223a7b2274797065223a352c226964223a226d61696e227d7d/RKSRS/Data-Analysis-Example-A-B/FreeCodeCamp1.ipynb#Y302sdnNjb2RlLXZmcw%3D%3D?line=0'>1</a> conn = sqlite3.connect('data/sakila.db')
#       <a href='vscode-notebook-cell://github%2B7b2276223a312c22726566223a7b2274797065223a352c226964223a226d61696e227d7d/RKSRS/Data-Analysis-Example-A-B/FreeCodeCamp1.ipynb#Y302sdnNjb2RlLXZmcw%3D%3D?line=2'>3</a> df = pd.read_sql('''
#       <a href='vscode-notebook-cell://github%2B7b2276223a312c22726566223a7b2274797065223a352c226964223a226d61696e227d7d/RKSRS/Data-Analysis-Example-A-B/FreeCodeCamp1.ipynb#Y302sdnNjb2RlLXZmcw%3D%3D?line=3'>4</a>     SELECT
# ...
